# %% [markdown]
# <a href="https://colab.research.google.com/github/Musu1/Udacity_DataScience/blob/master/4PolynomialRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd;
import numpy as np;
from sklearn.linear_model import LinearRegression;
from sklearn.preprocessing import PolynomialFeatures;
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data.csv')
x=data['Var_X'].values.reshape(-1,1)
y=data['Var_Y'].values

# %%
poly_feature=PolynomialFeatures(degree=9);
x_poly=poly_feature.fit_transform(x)

# %%
model=LinearRegression()
model.fit(x_poly,y)
y_poly_pred=model.predict(x_poly)

# %%
plt.scatter(x,y)
plt.plot(x,y_poly_pred)
plt.show()
